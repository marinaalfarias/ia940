# %% [markdown]
# <a href="https://colab.research.google.com/github/marinaalfarias/ia940/blob/main/AlturaVSdura%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio

# %% [markdown]
# Existe uma relação entre a duração do sinal e a percepção de altura, dada por $\Delta t \Delta f > $ cte. Se o sinal for muito curto, haverá um espalhamento espectral, ou seja, ele deixa de ser percebido como um tom e passa a ser percebido como um impulso.
#
# Variando o valor de "duration" e "frequency", dá para avaliar esta situação vocês mesmos.

# %%
duration = 10 #in miliseconds
frequency = 5000
amplitude = .1
sample_rate = 44100

time = np.arange(0, duration/1000, 1/sample_rate)
sinewave = amplitude * np.sin(2 * np.pi * frequency * time)
audio = sinewave * np.hanning(len(sinewave))

plt.figure(figsize=(20, 6), dpi=80)
plt.plot(time*1000,audio)
plt.xlabel('Tempo (ms)')
plt.ylabel('Amplitude')

Audio(audio, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Parâmetros gerais
duration = 5.0  # 5 segundos
sample_rate = 44100
amplitude = 0.1
f1 = 440

# Vetor de tempo
time = np.linspace(0, duration, int(sample_rate * duration), endpoint=False)
window = np.hanning(len(time))

# --------------------------------------------------
# Experimento 1: Frequência f (440 Hz) + 2f (880 Hz)
# --------------------------------------------------
f2_exp1 = 2 * f1
f2_exp2 = 1.05 * f1

sin1 = amplitude * np.sin(2 * np.pi * f1 * time)
sin2 = amplitude * np.sin(2 * np.pi * f2_exp1 * time)
sin3 = amplitude * np.sin(2 * np.pi * f2_exp2 * time)

audio1 = (sin1) * window
audio2 = (sin2) * window
audio3 = (sin3) * window
audiot = (sin1 + sin2) * window

# Reproduzir Experimento 1
#Audio(audio1, rate=sample_rate)
#Audio(audio2, rate=sample_rate)
Audio(audio3, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
